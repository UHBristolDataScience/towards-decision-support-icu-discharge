# %% [markdown]
# # Data Extraction from MIMIC.

# %% [markdown]
# ### Contents:
#
# * (A) Locating the required data
# * (B) Extracting the data
# * (C) Post-processing of data (involves combining with cohort information from 'cohort_selection_mimic.ipynb')
#
# We use two mysql libraries:
#
# * 'sql' is simple for scripting, with line/cell magic.
# * 'MySQLdb' is required for more complex operations (e.g. parameter binding with python lists).

# %%
import graphlab
import numpy as np
import pickle
import datetime
from collections import OrderedDict
import matplotlib.pyplot as plt
import matplotlib.dates as dates
# %matplotlib inline
# Out:
# This non-commercial license of GraphLab Create for academic use is assigned to cm1788@bristol.ac.uk and will expire on October 04, 2019.
# [INFO] graphlab.cython.cy_server: GraphLab Create v2.1 started. Logging: /tmp/graphlab_server_1540983808.log

# %%
# %load_ext sql
# %sql mysql://root:mysql2016@localhost/MIMIC?unix_socket=/run/mysqld/mysqld.sock
# %sql USE MIMIC
# Out:
# /home/rusty/anaconda3/lib/python2.7/site-packages/IPython/config.py:13: ShimWarning: The `IPython.config` package has been deprecated since IPython 4.0. You should import from traitlets.config instead.
#   "You should import from traitlets.config instead.", ShimWarning)
# /home/rusty/anaconda3/lib/python2.7/site-packages/IPython/utils/traitlets.py:5: UserWarning: IPython.utils.traitlets has moved to a top-level traitlets package.
#   warn("IPython.utils.traitlets has moved to a top-level traitlets package.")
# 0 rows affected.
# /home/rusty/anaconda3/lib/python2.7/site-packages/sqlalchemy/dialects/mysql/base.py:1569: Warning: '@@tx_isolation' is deprecated and will be removed in a future release. Please use '@@transaction_isolation' instead
#   cursor.execute('SELECT @@tx_isolation')
# []

# %% [markdown]
# ### (A) Locating the required data.
#
# A number of different variables are required to assess the nurse led discharge (NLD) criteria. Here we locate the ITEMIDs corresponding to these variables, which will be used to extract patient data from chartevents.
#
# For simplicity we focus on (dbsource=)'Metavision' only since data storage within 'Carevue' is less coherent. Because the study compares with a general intensive care unit (GICU) from the UK, we take only patients with (first_careunit=)'MICU' or 'SICU' since this patient subset approximately corresponds to the GICU population.
#
# The required variables are:

# %% [raw]
# > fio2: fractional inspired O2
# > resp: respiratory rate
# > po2/pco2: partial pressure of arterial O2/CO2
# > temp: temperature
# > hr: heart rate
# > bp: systolic blood pressure
# > k: potassium
# > na: sodium
# > hco3: bicarbonate
# > spo2: O2 saturation
# > bun: blood urea nitrogen (urea)
# > airway: patent airway (we determine by looking for presence of tracheostemy tube)
# > gcs: glasgow coma scale
# > creatinine: creatinine
# > pain: pain score
# > urine: urine output
# > haemo: haemoglobin
# > peep: positive end expiratory pressure (determine mech vent)

# %% [markdown]
# #### To locate these variables we proceed as follows:
#
# We define these search terms:

# %% [raw]
# > fio2: '%fractional%', '%fio2%'
# > resp: '%resp%', '%rate%'
# > po2/pco2: '%partial%', '%o2%', '%oxygen%'
# > temp: '%temp%'
# > hr: '%heart%', '%hr%'
# > bp: '%blood%', '%systolic%'
# > k: '%potassium%'
# > na: '%sodium%'
# > hco3: '%hc03%'
# > spo2: '%saturation%', '%o2%'
# > bun: '%urea%', '%bun%'
# > airway: '%ett%', '%trach%'
# > gcs: '%gcs%'
# > creatinine: '%creatinine%'
# > pain: '%pain%'
# > urine: '%urine%'
# > haemo: '%hemog%'
# > peep: '%peep%'

# %% [markdown]
# And search for ITEMIDS with LABELS that match the search terms using the following query:

# %%
# %sql SELECT * FROM D_ITEMS WHERE (LABEL LIKE '%fraction%' OR LABEL LIKE 'fio2') AND DBSOURCE='metavision'
# Out:
# 3 rows affected.
# [(12804, 223835, 'Inspired O2 Fraction', 'FiO2', 'metavision', 'chartevents', 'Respiratory', 'None', 'Numeric', None, 26L),
#  (14083, 225628, 'CK-MB fraction (%)', 'CK-MB fraction (%)', 'metavision', 'chartevents', 'Labs', 'None', 'Numeric', None, None),
#  (14685, 227008, 'Ejection Fraction', 'Ejection Fraction', 'metavision', 'chartevents', 'Scores - APACHE IV (2)', '%', 'Numeric', None, None)]

# %% [markdown]
# For each variable we visually inspect the search ouptut and select the ITEMS that appear relevant.
#
# *For example, for FiO2 we select 226754, 227009, 227010,223835 as candidates.*
#
# We then measure the approximate frequnecy of the candidate variables on a random subset of the data (i.e. how many ICUSTAYS have at least one recording of each ITEMID)...

# %%
sub_limit = 100  ## subset size: number of ICUSTAYS randomly selected

# %%
# %sql SELECT D.ITEMID, D.LABEL, COUNT(DISTINCT(II.ICUSTAY_ID)) AS STAY_COUNT, (COUNT(DISTINCT(II.ICUSTAY_ID))/(:sub_limit)) AS FREQ \
FROM CHARTEVENTS C \
INNER JOIN ( \
    SELECT * FROM ( \
        SELECT * \
        FROM ICUSTAYS I \
        WHERE I.DBSOURCE='metavision' AND (I.FIRST_CAREUNIT='MICU' or I.FIRST_CAREUNIT='SICU') \
        ORDER BY RAND() \
        LIMIT :sub_limit) AS II_sub \
    ORDER BY II_sub.SUBJECT_ID, II_sub.HADM_ID, II_sub.ICUSTAY_ID \
            ) AS II \
ON (C.SUBJECT_ID=II.SUBJECT_ID \
    AND C.HADM_ID=II.HADM_ID \
    AND C.ICUSTAY_ID=II.ICUSTAY_ID) \
INNER JOIN D_ITEMS D \
ON C.ITEMID=D.ITEMID \
WHERE D.ITEMID IN (226754, 227009, 227010, 223835) \
GROUP BY D.ITEMID
# Out:
# 1 rows affected.
# [(223835, 'Inspired O2 Fraction', 41L, Decimal('0.4100'))]

# %% [markdown]
# ..and manually inspect the first few instances of each ITEM to confirm it contains the required data (correct units and order of magnitude):

# %%
# %sql SELECT * FROM CHARTEVENTS WHERE ITEMID=223835 LIMIT 5
# Out:
# 5 rows affected.
# [(335L, 34, 144319, 290505, 223835, datetime.datetime(2191, 2, 23, 7, 31), datetime.datetime(2191, 2, 23, 7, 35), 16924, '60', 60.0, None, 0, 0, None, None),
#  (430L, 34, 144319, 290505, 223835, datetime.datetime(2191, 2, 23, 11, 0), datetime.datetime(2191, 2, 23, 11, 4), 14913, '60', 60.0, None, 0, 0, None, None),
#  (706L, 36, 165660, 241249, 223835, datetime.datetime(2134, 5, 12, 7, 9), datetime.datetime(2134, 5, 12, 7, 9), 17525, '100', 100.0, None, 0, 0, None, None),
#  (789L, 36, 165660, 241249, 223835, datetime.datetime(2134, 5, 12, 12, 0), datetime.datetime(2134, 5, 12, 13, 56), 17525, '100', 100.0, None, 0, 0, None, None),
#  (877L, 36, 165660, 241249, 223835, datetime.datetime(2134, 5, 12, 16, 13), datetime.datetime(2134, 5, 12, 16, 27), 18428, '100', 100.0, None, 0, 0, None, None)]

# %% [markdown]
# *For example ITEMID 223835 (Inspired O2 Fraction) contains numeric fractional data, and is measured with a reasonably high frequency (~0.4 to 0.6). We connclude that this is a relevant ITEM.*

# %% [markdown]
# #### By the above procedure we identify the following ITEMIDS corresponding to the required variables:
#
# * Some ITEMIDS may not be in (frequent) use in the database
# * Urine output may be located in either CHARTEVENTS or OUTPUTEVENTS (we check both)

# %%
# %sql SELECT * FROM D_ITEMS WHERE ITEMID=220224 LIMIT 5
# Out:
# 1 rows affected.
# [(12740, 220224, 'Arterial O2 pressure', 'PO2 (Arterial)', 'metavision', 'chartevents', 'Labs', 'mmHg', 'Numeric', None, 8L)]

# %% [raw]
# > fio2: (226754, 227009, 227010,223835)
# > resp: (220210, 224688, 224689, 224690)
# > po2:  (226770,227039,227516,220224)  ## 227516 is venous.
# > pco2: (220235,226062,226063,227036)  ## 226062,226063 are venous.
# > temp: (223761, 223762, 224027)
# > hr: (220045)
# > bp: (220050, 220059, 220179, 224167, 225309, 227243, 226850, 226852, 228151)
#
# > k:  (220640, 227464, 227442, 226772, 226535)
# > na: (220645, 226534, 226776)
# > hco3: (224826, 226759, 227443)
# > spo2: (220227, 220277, 226860,226861,226862,226863,226865,228232)
# > bun:  (225624, 227000, 227001)
# > airway: (223838, 224832, 224391, 227810,223837, 224829)
#
# > gcs:  (220739, 223900, 223901, 226755, 226756, 226757, 226758, 227011, 227012, 227013, 227014,228112)
# > creatinine: (220615, 226752, 227005)
# > pain: (223791, 227881)
#
# ? urine (chartevents): (227519, 227059)
# ? urine (outputevents): (226566, 226627, 226631)
#
# > haemoglobin: (220228)
# > peep: (220339, 224699, 224700)

# %% [markdown]
# **As a single list this is** (220739, 223900, 223901, 226755, 226756, 226757, 226758, 227011, 227012, 227013, 227014,228112, 220615, 226752, 227005, 223791, 227881, 227519, 227059, 220640, 227464, 227442, 226772, 226535, 220645, 226534, 226776, 224826, 226759, 227443,220227, 220277, 226860,226861,226862,226863,226865,228232, 225624, 227000, 227001, 223838, 224832, 224391, 227810,223837, 224829, 226754, 227009, 227010,223835, 220210, 224688, 224689, 224690, 226770,227039,227516,220224,220235,226062,226063,227036, 223761, 223762, 224027, 220045, 220228, 220339, 224699, 224700, 220050, 220059, 220179, 224167, 225309, 227243, 226850, 226852, 228151) ** for CHARTEVENTS.**
#
# ** And ** (226566, 226627, 226631) **for OUTPUTEVENTS (urine output only).**

# %% [markdown]
# -------------------------------------
# ## (B) Extracting the data
#
# Having located the relevant ITEMIDs we now:
#
# * Calculate their usage frequency from a larger random sample of ICUSTAYS
# * Define a cuttoff frequency
# * Extract and save all measurements of the remaining variables

# %%
sub_limit=1000  ## size of random sample

# %% [markdown]
# As before we calculate how many ICUSTAYS have at least one measurement of each ITEM, and convert this to an occurence frequnecy (FREQ). This time we calculate for all ITEMIDs simultaneoulsy, and sort the results by ascending occurence frequency. For CHARTEVENTS:

# %%
# %sql SELECT D.ITEMID, D.LABEL, COUNT(DISTINCT(II.ICUSTAY_ID)) AS STAY_COUNT, (COUNT(DISTINCT(II.ICUSTAY_ID))/(:sub_limit)) AS FREQ \
FROM CHARTEVENTS C \
INNER JOIN ( \
    SELECT * FROM ( \
        SELECT * \
        FROM ICUSTAYS I \
        WHERE I.DBSOURCE='metavision' AND (I.FIRST_CAREUNIT='MICU' or I.FIRST_CAREUNIT='SICU') \
        ORDER BY RAND() \
        LIMIT :sub_limit) AS II_sub \
    ORDER BY II_sub.SUBJECT_ID, II_sub.HADM_ID, II_sub.ICUSTAY_ID \
            ) AS II \
ON (C.SUBJECT_ID=II.SUBJECT_ID \
    AND C.HADM_ID=II.HADM_ID \
    AND C.ICUSTAY_ID=II.ICUSTAY_ID) \
INNER JOIN D_ITEMS D \
ON C.ITEMID=D.ITEMID \
WHERE D.ITEMID IN (220739, 223900, 223901, 226755, 226756, 226757, 226758, 227011, 227012, 227013, 227014,228112, 220615, 226752, 227005, 223791, 227881, 227519, 227059, 220640, 227464, 227442, 226772, 226535, 220645, 226534, 226776, 224826, 226759, 227443,220227, 220277, 226860,226861,226862,226863,226865,228232, 225624, 227000, 227001, 223838, 224832, 224391, 227810,223837, 224829, 226754, 227009, 227010,223835, 220210, 224688, 224689, 224690, 226770,227039,227516,220224,220235,226062,226063,227036, 223761, 223762, 224027, 220045, 220228, 220339, 224699, 224700, 220050, 220059, 220179, 224167, 225309, 227243, 226850, 226852, 228151) \
GROUP BY D.ITEMID \
ORDER BY FREQ
# Out:
# 59 rows affected.
# [(226752, 'CreatinineApacheIIValue', 1L, Decimal('0.0010')),
#  (226754, 'FiO2ApacheIIValue', 1L, Decimal('0.0010')),
#  (226755, 'GcsApacheIIScore', 1L, Decimal('0.0010')),
#  (226756, 'GCSEyeApacheIIValue', 1L, Decimal('0.0010')),
#  (226757, 'GCSMotorApacheIIValue', 1L, Decimal('0.0010')),
#  (226758, 'GCSVerbalApacheIIValue', 1L, Decimal('0.0010')),
#  (226759, 'HCO3ApacheIIValue', 1L, Decimal('0.0010')),
#  (226772, 'PotassiumApacheIIValue', 1L, Decimal('0.0010')),
#  (226776, 'SodiumApacheIIValue', 1L, Decimal('0.0010')),
#  (227000, 'BUN_ApacheIV', 1L, Decimal('0.0010')),
#  (227001, 'BunScore_ApacheIV', 1L, Decimal('0.0010')),
#  (227005, 'Creatinine_ApacheIV', 1L, Decimal('0.0010')),
#  (227013, 'GcsScore_ApacheIV', 1L, Decimal('0.0010')),
#  (227059, 'UrineScore_ApacheIV', 1L, Decimal('0.0010')),
#  (227519, 'Urine output_ApacheIV', 1L, Decimal('0.0010')),
#  (227881, 'Pain (0-10)', 1L, Decimal('0.0010')),
#  (227243, 'Manual Blood Pressure Systolic Right', 3L, Decimal('0.0030')),
#  (224167, 'Manual Blood Pressure Systolic Left', 6L, Decimal('0.0060')),
#  (220059, 'Pulmonary Artery Pressure systolic', 17L, Decimal('0.0170')),
#  (228232, 'PAR-Oxygen saturation', 20L, Decimal('0.0200')),
#  (224829, 'Trach Tube Type', 42L, Decimal('0.0420')),
#  (223762, 'Temperature Celsius', 44L, Decimal('0.0440')),
#  (227516, 'PO2 (Mixed Venous)', 48L, Decimal('0.0480')),
#  (225309, 'ART BP Systolic', 49L, Decimal('0.0490')),
#  (227810, 'ETT Re-taped', 113L, Decimal('0.1130')),
#  (226062, 'Venous CO2 Pressure', 116L, Decimal('0.1160')),
#  (226063, 'Venous O2 Pressure', 116L, Decimal('0.1160')),
#  (226534, 'Sodium (whole blood)', 125L, Decimal('0.1250')),
#  (224391, 'ETT Mark (location)', 164L, Decimal('0.1640')),
#  (220227, 'Arterial O2 Saturation', 185L, Decimal('0.1850')),
#  (227464, 'Potassium (whole blood)', 200L, Decimal('0.2000')),
#  (224700, 'Total PEEP Level', 225L, Decimal('0.2250')),
#  (220050, 'Arterial Blood Pressure systolic', 310L, Decimal('0.3100')),
#  (224688, 'Respiratory Rate (Set)', 313L, Decimal('0.3130')),
#  (223838, 'ETT Location', 316L, Decimal('0.3160')),
#  (223837, 'ETT Size (ID)', 317L, Decimal('0.3170')),
#  (224832, 'ETT Type', 318L, Decimal('0.3180')),
#  (224690, 'Respiratory Rate (Total)', 344L, Decimal('0.3440')),
#  (224689, 'Respiratory Rate (spontaneous)', 364L, Decimal('0.3640')),
#  (220339, 'PEEP set', 370L, Decimal('0.3700')),
#  (220224, 'Arterial O2 pressure', 447L, Decimal('0.4470')),
#  (220235, 'Arterial CO2 Pressure', 447L, Decimal('0.4470')),
#  (223835, 'Inspired O2 Fraction', 475L, Decimal('0.4750')),
#  (223791, 'Pain Level', 907L, Decimal('0.9070')),
#  (220228, 'Hemoglobin', 966L, Decimal('0.9660')),
#  (225624, 'BUN', 966L, Decimal('0.9660')),
#  (220615, 'Creatinine', 969L, Decimal('0.9690')),
#  (220645, 'Sodium (serum)', 969L, Decimal('0.9690')),
#  (227442, 'Potassium (serum)', 969L, Decimal('0.9690')),
#  (227443, 'HCO3 (serum)', 969L, Decimal('0.9690')),
#  (220179, 'Non Invasive Blood Pressure systolic', 978L, Decimal('0.9780')),
#  (223761, 'Temperature Fahrenheit', 983L, Decimal('0.9830')),
#  (224027, 'Skin Temperature', 984L, Decimal('0.9840')),
#  (220045, 'Heart Rate', 987L, Decimal('0.9870')),
#  (220210, 'Respiratory Rate', 987L, Decimal('0.9870')),
#  (220277, 'O2 saturation pulseoxymetry', 987L, Decimal('0.9870')),
#  (220739, 'GCS - Eye Opening', 987L, Decimal('0.9870')),
#  (223900, 'GCS - Verbal Response', 987L, Decimal('0.9870')),
#  (223901, 'GCS - Motor Response', 987L, Decimal('0.9870'))]

# %% [markdown]
# ..and for OUTPUTEVENTS:

# %%
# %sql SELECT D.ITEMID, D.LABEL, COUNT(DISTINCT(II.ICUSTAY_ID)) AS STAY_COUNT, (COUNT(DISTINCT(II.ICUSTAY_ID))/(:sub_limit)) AS FREQ \
FROM OUTPUTEVENTS C \
INNER JOIN ( \
    SELECT * FROM ( \
        SELECT * \
        FROM ICUSTAYS I \
        WHERE I.DBSOURCE='metavision' AND (I.FIRST_CAREUNIT='MICU' or I.FIRST_CAREUNIT='SICU') \
        ORDER BY RAND() \
        LIMIT :sub_limit) AS II_sub \
    ORDER BY II_sub.SUBJECT_ID, II_sub.HADM_ID, II_sub.ICUSTAY_ID \
            ) AS II \
ON (C.SUBJECT_ID=II.SUBJECT_ID \
    AND C.HADM_ID=II.HADM_ID \
    AND C.ICUSTAY_ID=II.ICUSTAY_ID) \
INNER JOIN D_ITEMS D \
ON C.ITEMID=D.ITEMID \
WHERE D.ITEMID IN (226566, 226627, 226631) \
GROUP BY D.ITEMID \
ORDER BY FREQ
# Out:
# 2 rows affected.
# [(226631, 'PACU Urine', 11L, Decimal('0.0110')),
#  (226627, 'OR Urine', 127L, Decimal('0.1270'))]

# %% [markdown]
# **Note:** we find that the 'Urine Output' ITEMs that we identified are not in frequent use. The difficulty of identifying urine in MIMIC has been previoulsy noted by others. We accept that we canot use 'Urine Output' and do not attempt further investigation.
#
# We now store the CHARTEVENTS query results into a dataframe, and remove those that are only recorded infrequently. This is done to simplify the subsequent analysis (and reduce the number of checks on data integrity), but we aknowledge that it will result in a small amount of missing data. We define a minimum usage frequency of 0.01 (1%).

# %%
freqs=%sql SELECT D.ITEMID, D.LABEL, COUNT(DISTINCT(II.ICUSTAY_ID)) AS STAY_COUNT, (COUNT(DISTINCT(II.ICUSTAY_ID))/(:sub_limit)) AS FREQ \
FROM CHARTEVENTS C \
INNER JOIN ( \
    SELECT * FROM ( \
        SELECT * \
        FROM ICUSTAYS I \
        WHERE I.DBSOURCE='metavision' AND (I.FIRST_CAREUNIT='MICU' or I.FIRST_CAREUNIT='SICU') \
        ORDER BY RAND() \
        LIMIT :sub_limit) AS II_sub \
    ORDER BY II_sub.SUBJECT_ID, II_sub.HADM_ID, II_sub.ICUSTAY_ID \
            ) AS II \
ON (C.SUBJECT_ID=II.SUBJECT_ID \
    AND C.HADM_ID=II.HADM_ID \
    AND C.ICUSTAY_ID=II.ICUSTAY_ID) \
INNER JOIN D_ITEMS D \
ON C.ITEMID=D.ITEMID \
WHERE D.ITEMID IN (220739, 223900, 223901, 226755, 226756, 226757, 226758, 227011, 227012, 227013, 227014,228112, 220615, 226752, 227005, 223791, 227881, 227519, 227059, 220640, 227464, 227442, 226772, 226535, 220645, 226534, 226776, 224826, 226759, 227443,220227, 220277, 226860,226861,226862,226863,226865,228232, 225624, 227000, 227001, 223838, 224832, 224391, 227810,223837, 224829, 226754, 227009, 227010,223835, 220210, 224688, 224689, 224690, 226770,227039,227516,220224,220235,226062,226063,227036, 223761, 223762, 224027, 220045, 220228, 220339, 224699, 224700, 220050, 220059, 220179, 224167, 225309, 227243, 226850, 226852, 228151) \
GROUP BY D.ITEMID \
ORDER BY FREQ

freqs=graphlab.SFrame(freqs.DataFrame())
freqs.print_rows(num_rows=4)
ITEMIDS = freqs[freqs['FREQ']>=0.01]['ITEMID']  ## cutoff = 0.01

ITEMIDS_TOREMOVE = freqs[freqs['FREQ']<0.01]['ITEMID']  ## remove these from variable mapping
# Out:
# 53 rows affected.
# +--------+-------------------------+------------+-------+
# | ITEMID |          LABEL          | STAY_COUNT |  FREQ |
# +--------+-------------------------+------------+-------+
# | 226752 | CreatinineApacheIIValue |     1      | 0.001 |
# | 226754 |    FiO2ApacheIIValue    |     1      | 0.001 |
# | 226755 |     GcsApacheIIScore    |     1      | 0.001 |
# | 226756 |   GCSEyeApacheIIValue   |     1      | 0.001 |
# +--------+-------------------------+------------+-------+
# [53 rows x 4 columns]

# %%
variable_mapping = dict()

variable_mapping['fio2'] = [226754, 227009, 227010,223835]
variable_mapping['resp'] = [220210, 224688, 224689, 224690]
variable_mapping['po2'] = [226770,227039,227516,220224]  ## 227516 is venous.
variable_mapping['pco2'] = [220235,226062,226063,227036]  ## 226062,226063 are venous.

variable_mapping['temp'] = [223761, 223762, 224027] 
variable_mapping['hr'] = [220045]
variable_mapping['bp'] = [220050, 220059, 220179, 224167, 225309, 227243, 226850, 226852, 228151]
variable_mapping['k'] = [220640, 227464, 227442, 226772, 226535]
variable_mapping['na'] = [220645, 226534, 226776]
variable_mapping['hco3'] = [224826, 226759, 227443]
variable_mapping['spo2'] = [220227, 220277, 226860,226861,226862,226863,226865,228232]
variable_mapping['bun'] = [225624, 227000, 227001]
variable_mapping['airway'] = [223838, 224832, 224391, 227810,223837, 224829]
variable_mapping['gcs'] = [220739, 223900, 223901, 226755, 226756, 226757, 226758, 227011, 227012, 227013, 227014,228112]
variable_mapping['creatinine'] = [220615, 226752, 227005]
variable_mapping['pain'] = [223791, 227881]
variable_mapping['urine'] = [227519, 227059]
variable_mapping['haemoglobin'] = [220228]
variable_mapping['peep'] = [220339, 224699, 224700]
                        
for var in variable_mapping:
        variable_mapping[var] = [itd for itd in variable_mapping[var] if itd not in ITEMIDS_TOREMOVE]
        
print variable_mapping
# Out:
# {'urine': [227519, 227059], 'pain': [223791], 'temp': [223761, 223762, 224027], 'hr': [220045], 'fio2': [227009, 227010, 223835], 'resp': [220210, 224688, 224689, 224690], 'airway': [223838, 224832, 224391, 227810, 223837, 224829], 'po2': [226770, 227039, 227516, 220224], 'hco3': [224826, 227443], 'peep': [220339, 224699, 224700], 'gcs': [220739, 223900, 223901, 227011, 227012, 227013, 227014, 228112], 'pco2': [220235, 226062, 226063, 227036], 'na': [220645, 226534], 'bun': [225624, 227000, 227001], 'bp': [220050, 220059, 220179, 225309, 226850, 226852, 228151], 'creatinine': [220615, 227005], 'k': [220640, 227464, 227442, 226535], 'spo2': [220227, 220277, 226860, 226861, 226862, 226863, 226865, 228232], 'haemoglobin': [220228]}

# %% [markdown]
# #### Finally we extract the data from CHARTEVENTS for all the selected ITEMIDS:

# %%
import MySQLdb
import MySQLdb.cursors
from contextlib import closing

db='MIMIC'
user='root'
password='mysql2016'

conn = MySQLdb.connect(host="localhost",
                     user=user, 
                     passwd=password, 
                     db=db,
                     unix_socket="/run/mysqld/mysqld.sock",
                     cursorclass = MySQLdb.cursors.SSCursor)  ## ensures correct behaviour for 'fetchone'

# %%
## test the connection (should only print one row if 'fetchone' is working correctly):
with closing(conn.cursor()) as cur:
    cur.execute('SELECT * FROM D_ITEMS WHERE LABEL LIKE "%urine%" AND DBSOURCE="metavision"')
    row = cur.fetchone()
    print row
# Out:
# (12710, 220799, 'ZSpecific Gravity (urine)', 'ZSpecific gravity (urine)', 'metavision', 'chartevents', 'Labs', 'None', 'Numeric', None, None)

# %%
#list_of_ids = [205254]
#list_of_ids.extend(ITEMIDS)
#format_strings = '%d,' + ','.join(['%s'] * len(list_of_ids))
list_of_ids = ITEMIDS
format_strings = ','.join(['%s'] * len(list_of_ids))

# %%
pull_query="""SELECT C.SUBJECT_ID, C.HADM_ID, C.ICUSTAY_ID, C.ITEMID, C.CHARTTIME, C.VALUE, C.VALUENUM, C.VALUEUOM, II.INTIME, II.OUTTIME, II.LOS, D.LABEL, D.UNITNAME 
FROM CHARTEVENTS C 
INNER JOIN ( 
    SELECT * 
    FROM ICUSTAYS I 
    WHERE I.DBSOURCE='metavision' AND (I.FIRST_CAREUNIT='MICU' or I.FIRST_CAREUNIT='SICU') 
    LIMIT 100000) AS II 
ON (C.SUBJECT_ID=II.SUBJECT_ID 
    AND C.HADM_ID=II.HADM_ID 
    AND C.ICUSTAY_ID=II.ICUSTAY_ID) 
INNER JOIN D_ITEMS D 
ON C.ITEMID=D.ITEMID 
WHERE D.ITEMID in (%s)"""

## Column headers for the dataframe in which we will store the query results:
cols = ['C.SUBJECT_ID', 'C.HADM_ID', 'C.ICUSTAY_ID', 'C.ITEMID', 'C.CHARTTIME', 'C.VALUE', 'C.VALUENUM', 'C.VALUEUOM', 'II.INTIME', 'II.OUTTIME', 'II.LOS', 'D.LABEL', 'D.UNITNAME']

# %% [markdown]
# We now extract the data. This is a big query. We use 'fetchone' one to grab the results row by row, and store them in a dictionary (keys=column names, values=list of column values).
#
# We use graphlab because is has out-of-memory storage for SFrames (no concern over size of result set).
# We save the SFrame intermittently and clear the results dictionary.

# %%
if False:
    data = None
    table = None
    subjectids = []
    max_len = 10000  ## buffer dictionary size (to reduce memory usage)

    with closing(conn.cursor()) as cur:
        cur.execute(pull_query %format_strings,tuple(list_of_ids))

        row = cur.fetchone()
        while row is not None:

            if data is None:
                ## results buffer is clear, begin new one
                row = [[element] for element in row]
                data = OrderedDict(zip(cols,row))
            else:
                ## append to existing results buffer
                new_row = dict(zip(cols,row))
                for key in data.keys():
                    data[key].append(new_row[key])

                if len(data['C.SUBJECT_ID']) >= max_len:
                    ## buffer is full.. 
                    if table is None:
                        table = graphlab.SFrame(data) ## creates SFrame from dictionary of columns
                        table.save('mimic_all_data')            
                    else:
                        table = table.append(graphlab.SFrame(data))
                        table.save('mimic_all_data')            

                        print "Saving SFrame..."
                        print "Number of icustays = %d" %(len(table['C.SUBJECT_ID'].unique()))

                    data = None ## clear buffer

            row = cur.fetchone()
# Out:
# Saving SFrame...
# Number of icustays = 114
# Saving SFrame...
# Number of icustays = 164
# Saving SFrame...
# Number of icustays = 224
# Saving SFrame...
# Number of icustays = 300
# Saving SFrame...
# Number of icustays = 320
# Saving SFrame...
# Number of icustays = 340
# Saving SFrame...
# Number of icustays = 406
# Saving SFrame...
# Number of icustays = 470
# Saving SFrame...
# Number of icustays = 545
# Saving SFrame...
# Number of icustays = 604
# Saving SFrame...
# Number of icustays = 654
# Saving SFrame...
# Number of icustays = 719
# Saving SFrame...
# Number of icustays = 775
# Saving SFrame...
# Number of icustays = 845
# Saving SFrame...
# Number of icustays = 909
# Saving SFrame...
# Number of icustays = 973
# Saving SFrame...
# Number of icustays = 1053
# Saving SFrame...
# Number of icustays = 1112
# Saving SFrame...
# Number of icustays = 1195
# Saving SFrame...
# Number of icustays = 1248
# Saving SFrame...
# Number of icustays = 1326
# Saving SFrame...
# Number of icustays = 1395
# Saving SFrame...
# Number of icustays = 1499
# Saving SFrame...
# Number of icustays = 1576
# Saving SFrame...
# Number of icustays = 1659
# Saving SFrame...
# Number of icustays = 1753
# Saving SFrame...
# Number of icustays = 1847
# Saving SFrame...
# Number of icustays = 1864
# Saving SFrame...
# Number of icustays = 1935
# Saving SFrame...
# Number of icustays = 2045
# Saving SFrame...
# Number of icustays = 2110
# Saving SFrame...
# Number of icustays = 2218
# Saving SFrame...
# Number of icustays = 2262
# Saving SFrame...
# Number of icustays = 2338
# Saving SFrame...
# Number of icustays = 2420
# Saving SFrame...
# Number of icustays = 2492
# Saving SFrame...
# Number of icustays = 2492
# Saving SFrame...
# Number of icustays = 2492
# Saving SFrame...
# Number of icustays = 2522
# Saving SFrame...
# Number of icustays = 2616
# Saving SFrame...
# Number of icustays = 2715
# Saving SFrame...
# Number of icustays = 2815
# Saving SFrame...
# Number of icustays = 2855
# Saving SFrame...
# Number of icustays = 2927
# Saving SFrame...
# Number of icustays = 2956
# Saving SFrame...
# Number of icustays = 3039
# Saving SFrame...
# Number of icustays = 3126
# Saving SFrame...
# Number of icustays = 3223
# Saving SFrame...
# Number of icustays = 3271
# Saving SFrame...
# Number of icustays = 3284
# Saving SFrame...
# Number of icustays = 3375
# Saving SFrame...
# Number of icustays = 3431
# Saving SFrame...
# Number of icustays = 3511
# Saving SFrame...
# Number of icustays = 3580
# Saving SFrame...
# Number of icustays = 3667
# Saving SFrame...
# Number of icustays = 3746
# Saving SFrame...
# Number of icustays = 3746
# Saving SFrame...
# Number of icustays = 3799
# Saving SFrame...
# Number of icustays = 3869
# Saving SFrame...
# Number of icustays = 3955
# Saving SFrame...
# Number of icustays = 4012
# Saving SFrame...
# Number of icustays = 4012
# Saving SFrame...
# Number of icustays = 4012
# Saving SFrame...
# Number of icustays = 4012
# Saving SFrame...
# Number of icustays = 4028
# Saving SFrame...
# Number of icustays = 4085
# Saving SFrame...
# Number of icustays = 4167
# Saving SFrame...
# Number of icustays = 4251
# Saving SFrame...
# Number of icustays = 4292
# Saving SFrame...
# Number of icustays = 4306
# Saving SFrame...
# Number of icustays = 4399
# Saving SFrame...
# Number of icustays = 4435
# Saving SFrame...
# Number of icustays = 4435
# Saving SFrame...
# Number of icustays = 4435
# Saving SFrame...
# Number of icustays = 4494
# Saving SFrame...
# Number of icustays = 4538
# Saving SFrame...
# Number of icustays = 4605
# Saving SFrame...
# Number of icustays = 4675
# Saving SFrame...
# Number of icustays = 4735
# Saving SFrame...
# Number of icustays = 4802
# Saving SFrame...
# Number of icustays = 4878
# Saving SFrame...
# Number of icustays = 4990
# Saving SFrame...
# Number of icustays = 5055
# Saving SFrame...
# Number of icustays = 5116
# Saving SFrame...
# Number of icustays = 5197
# Saving SFrame...
# Number of icustays = 5269
# Saving SFrame...
# Number of icustays = 5363
# Saving SFrame...
# Number of icustays = 5462
# Saving SFrame...
# Number of icustays = 5534
# Saving SFrame...
# Number of icustays = 5595
# Saving SFrame...
# Number of icustays = 5614
# Saving SFrame...
# Number of icustays = 5691
# Saving SFrame...
# Number of icustays = 5770
# Saving SFrame...
# Number of icustays = 5850
# Saving SFrame...
# Number of icustays = 5957
# Saving SFrame...
# Number of icustays = 6029
# Saving SFrame...
# Number of icustays = 6091
# Saving SFrame...
# Number of icustays = 6184
# Saving SFrame...
# Number of icustays = 6272
# Saving SFrame...
# Number of icustays = 6338
# Saving SFrame...
# Number of icustays = 6389
# Saving SFrame...
# Number of icustays = 6438
# Saving SFrame...
# Number of icustays = 6519
# Saving SFrame...
# Number of icustays = 6630
# Saving SFrame...
# Number of icustays = 6701
# Saving SFrame...
# Number of icustays = 6763
# Saving SFrame...
# Number of icustays = 6837
# Saving SFrame...
# Number of icustays = 6901
# Saving SFrame...
# Number of icustays = 6997
# Saving SFrame...
# Number of icustays = 7062
# Saving SFrame...
# Number of icustays = 7143
# Saving SFrame...
# Number of icustays = 7221
# Saving SFrame...
# Number of icustays = 7270
# Saving SFrame...
# Number of icustays = 7340
# Saving SFrame...
# Number of icustays = 7422
# Saving SFrame...
# Number of icustays = 7494
# Saving SFrame...
# Number of icustays = 7549
# Saving SFrame...
# Number of icustays = 7622
# Saving SFrame...
# Number of icustays = 7707
# Saving SFrame...
# Number of icustays = 7769
# Saving SFrame...
# Number of icustays = 7846
# Saving SFrame...
# Number of icustays = 7910
# Saving SFrame...
# Number of icustays = 7991
# Saving SFrame...
# Number of icustays = 8074
# Saving SFrame...
# Number of icustays = 8168
# Saving SFrame...
# Number of icustays = 8256
# Saving SFrame...
# Number of icustays = 8347
# Saving SFrame...
# Number of icustays = 8403
# Saving SFrame...
# Number of icustays = 8403
# Saving SFrame...
# Number of icustays = 8403
# Saving SFrame...
# Number of icustays = 8419
# Saving SFrame...
# Number of icustays = 8507
# Saving SFrame...
# Number of icustays = 8615
# Saving SFrame...
# Number of icustays = 8719
# Saving SFrame...
# Number of icustays = 8797
# Saving SFrame...
# Number of icustays = 8883
# Saving SFrame...
# Number of icustays = 8991
# Saving SFrame...
# Number of icustays = 9058
# Saving SFrame...
# Number of icustays = 9175
# Saving SFrame...
# Number of icustays = 9237
# Saving SFrame...
# Number of icustays = 9237
# Saving SFrame...
# Number of icustays = 9272
# Saving SFrame...
# Number of icustays = 9333
# Saving SFrame...
# Number of icustays = 9333
# Saving SFrame...
# Number of icustays = 9333
# Saving SFrame...
# Number of icustays = 9333
# Saving SFrame...
# Number of icustays = 9333
# Saving SFrame...
# Number of icustays = 9376
# Saving SFrame...
# Number of icustays = 9472
# Saving SFrame...
# Number of icustays = 9551
# Saving SFrame...
# Number of icustays = 9633
# Saving SFrame...
# Number of icustays = 9717
# Saving SFrame...
# Number of icustays = 9757
# Saving SFrame...
# Number of icustays = 9852
# Saving SFrame...
# Number of icustays = 9934
# Saving SFrame...
# Number of icustays = 10019
# Saving SFrame...
# Number of icustays = 10107
# Saving SFrame...
# Number of icustays = 10184
# Saving SFrame...
# Number of icustays = 10262
# Saving SFrame...
# Number of icustays = 10345
# Saving SFrame...
# Number of icustays = 10428
# Saving SFrame...
# Number of icustays = 10478
# Saving SFrame...
# Number of icustays = 10542
# Saving SFrame...
# Number of icustays = 10656
# Saving SFrame...
# Number of icustays = 10715
# Saving SFrame...
# Number of icustays = 10787
# Saving SFrame...
# Number of icustays = 10862
# Saving SFrame...
# Number of icustays = 10921
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10942
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10943
# Saving SFrame...
# Number of icustays = 10945
# Saving SFrame...
# Number of icustays = 10947
# Saving SFrame...
# Number of icustays = 10947
# Saving SFrame...
# Number of icustays = 10950
# Saving SFrame...
# Number of icustays = 10953
# Saving SFrame...
# Number of icustays = 10954
# Saving SFrame...
# Number of icustays = 10954
# Saving SFrame...
# Number of icustays = 10958
# Saving SFrame...
# Number of icustays = 10959
# Saving SFrame...
# Number of icustays = 10959
# Saving SFrame...
# Number of icustays = 10959
# Saving SFrame...
# Number of icustays = 10959
# Saving SFrame...
# Number of icustays = 10960
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10962
# Saving SFrame...
# Number of icustays = 10963
# Saving SFrame...
# Number of icustays = 10963
# Saving SFrame...
# Number of icustays = 10963
# Saving SFrame...
# Number of icustays = 10963
# Saving SFrame...
# Number of icustays = 10963
# Saving SFrame...
# Number of icustays = 10963
# Saving SFrame...
# Number of icustays = 10963
# Saving SFrame...
# Number of icustays = 10963
# Saving SFrame...
# Number of icustays = 10963
# Saving SFrame...
# Number of icustays = 10963
# Saving SFrame...
# Number of icustays = 10963
# Saving SFrame...
# Number of icustays = 10963
# Saving SFrame...
# Number of icustays = 10963
# Saving SFrame...
# Number of icustays = 10963
# Saving SFrame...
# Number of icustays = 10963
# Saving SFrame...
# Number of icustays = 10963
# Saving SFrame...
# Number of icustays = 10963
# Saving SFrame...
# Number of icustays = 10963
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-25-82c15f2c6ccb> in <module>()
#      34                 data = None ## clear buffer
#      35
# ---> 36         row = cur.fetchone()
#
# /home/rusty/anaconda3/lib/python2.7/contextlib.pyc in __exit__(self, *exc_info)
#     152         return self.thing
#     153     def __exit__(self, *exc_info):
# --> 154         self.thing.close()
#
# /home/rusty/anaconda3/lib/python2.7/site-packages/MySQLdb/cursors.pyc in close(self)
#      98         """Close the cursor. No further queries will be possible."""
#      99         if not self.connection: return
# --> 100         while self.nextset(): pass
#     101         self.connection = None
#     102
#
# /home/rusty/anaconda3/lib/python2.7/site-packages/MySQLdb/cursors.pyc in nextset(self)
#     126         """
#     127         if self._executed:
# --> 128             self.fetchall()
#     129         del self.messages[:]
#     130
#
# /home/rusty/anaconda3/lib/python2.7/site-packages/MySQLdb/cursors.pyc in fetchall(self)
#     448         """Fetchs all available rows from the cursor."""
#     449         self._check_executed()
# --> 450         r = self._fetch_row(0)
#     451         self.rownumber = self.rownumber + len(r)
#     452         self._warning_check()
#
# /home/rusty/anaconda3/lib/python2.7/site-packages/MySQLdb/cursors.pyc in _fetch_row(self, size)
#     325         if not self._result:
#     326             return ()
# --> 327         return self._result.fetch_row(size, self._fetch_type)
#     328
#     329     def __iter__(self):
#
# OperationalError: (2013, 'Lost connection to MySQL server during query')

# %% [markdown]
# ### Running full extraction in one go kept crashing (MySQL time out). So now we run in stages and then recombine all data at the end:

# %%
partial_pull_query0 ="""SELECT C.SUBJECT_ID, C.HADM_ID, C.ICUSTAY_ID, C.ITEMID, C.CHARTTIME, C.VALUE, C.VALUENUM, C.VALUEUOM, II.INTIME, II.OUTTIME, II.LOS, D.LABEL, D.UNITNAME 
FROM CHARTEVENTS C 
INNER JOIN ( 
    SELECT * 
    FROM ICUSTAYS I 
    WHERE I.DBSOURCE='metavision' AND (I.FIRST_CAREUNIT='MICU' or I.FIRST_CAREUNIT='SICU') AND I.ICUSTAY_ID>=%d AND I.ICUSTAY_ID<=%d AND I.ICUSTAY_ID NOT IN (249026,254172)"""

partial_pull_query1="""
    LIMIT 100000) AS II 
ON (C.SUBJECT_ID=II.SUBJECT_ID 
    AND C.HADM_ID=II.HADM_ID 
    AND C.ICUSTAY_ID=II.ICUSTAY_ID) 
INNER JOIN D_ITEMS D 
ON C.ITEMID=D.ITEMID 
WHERE D.ITEMID in (%s)"""

## Column headers for the dataframe in which we will store the query results:
cols = ['C.SUBJECT_ID', 'C.HADM_ID', 'C.ICUSTAY_ID', 'C.ITEMID', 'C.CHARTTIME', 'C.VALUE', 'C.VALUENUM', 'C.VALUEUOM', 'II.INTIME', 'II.OUTTIME', 'II.LOS', 'D.LABEL', 'D.UNITNAME']

# %%
min_id = 200000
max_id = 300000
boundary_ids = []
start = min_id
end = min_id + 1000
while end<=max_id:
    boundary_ids.append((start,end))
    start+=1000
    end+=1000

# %%
#len(boundary_ids)
boundary_ids[49]
# Out:
# (249000, 250000)

# %% [markdown]
# #### Piecewise code below crashing on 49th and 54th boundary. Let split this further:

# %%
min_id = 249000
max_id = 249100
_sub_boundary_ids = []
start = min_id
end = min_id + 10
while end<=max_id:
    _sub_boundary_ids.append((start,end))
    start+=100
    end+=100

# %% [markdown]
# ### Problematic icustay ids!
# #### Not clear why. Too muc data in single stay?
# #### If not many then shouldn't affect results.

# %%
problem_ids = [249026, 254172]

# %%
for boundary in boundary_ids[54:]:
#for boundary in boundary_ids[49:]:
#for boundary in [(249027,249030)]:
#for boundary in _sub_boundary_ids:
    
    data = None
    table = None
    
    print "Beginning: " + str(boundary)
    
    with closing(conn.cursor()) as cur:
        cur.execute(partial_pull_query0 %(boundary[0],boundary[1]) + partial_pull_query1 %format_strings,tuple(list_of_ids))

        print "   intitial query complete"
        row = cur.fetchone()
        while row is not None:
            
            if data is None:
                ## results buffer is clear, begin new one
                row = [[element] for element in row]
                data = OrderedDict(zip(cols,row))
            else:
                ## append to existing results buffer
                new_row = dict(zip(cols,row))
                for key in data.keys():
                    data[key].append(new_row[key])

            STAY = data['C.ICUSTAY_ID']
            row = cur.fetchone() 
    print "   extracted all rows. Saving SFrame.."
    table = graphlab.SFrame(data) ## creates SFrame from dictionary of columns
    table.save('_temp_mimic_all_data_' + str(boundary))            
    print "Completed: " + str(boundary)
# Out:
# Beginning: (254000, 255000)
#    intitial query complete
#    extracted all rows. Saving SFrame..
# Completed: (254000, 255000)
# Beginning: (255000, 256000)
#    intitial query complete
#    extracted all rows. Saving SFrame..
# Completed: (255000, 256000)
# Beginning: (256000, 257000)
#    intitial query complete
#    extracted all rows. Saving SFrame..
# Completed: (256000, 257000)
# Beginning: (257000, 258000)
#    intitial query complete
#    extracted all rows. Saving SFrame..
# Completed: (257000, 258000)
# Beginning: (258000, 259000)
#    intitial query complete
#    extracted all rows. Saving SFrame..
# Completed: (258000, 259000)
# Beginning: (259000, 260000)
#    intitial query complete
#    extracted all rows. Saving SFrame..
# Completed: (259000, 260000)
# Beginning: (260000, 261000)
#    intitial query complete
#    extracted all rows. Saving SFrame..
# Completed: (260000, 261000)
# Beginning: (261000, 262000)
#    intitial query complete
#    extracted all rows. Saving SFrame..
# Completed: (261000, 262000)
# Beginning: (262000, 263000)
#    intitial query complete
#    extracted all rows. Saving SFrame..
# Completed: (262000, 263000)
# Beginning: (263000, 264000)
#    intitial query complete
#    extracted all rows. Saving SFrame..
# Completed: (263000, 264000)
# Beginning: (264000, 265000)
#    intitial query complete
#    extracted all rows. Saving SFrame..
# Completed: (264000, 265000)
# Beginning: (265000, 266000)
#    intitial query complete
#    extracted all rows. Saving SFrame..
# Completed: (265000, 266000)
# Beginning: (266000, 267000)
#    intitial query complete
#    extracted all rows. Saving SFrame..
# Completed: (266000, 267000)
# Beginning: (267000, 268000)
#    intitial query complete
#    extracted all rows. Saving SFrame..
# Completed: (267000, 268000)
# Beginning: (268000, 269000)
#    intitial query complete
#    extracted all rows. Saving SFrame..
# Completed: (268000, 269000)
# Beginning: (269000, 270000)
#    intitial query complete
#    extracted all rows. Saving SFrame..
# Completed: (269000, 270000)
# Beginning: (270000, 271000)
#    intitial query complete
#    extracted all rows. Saving SFrame..
# Completed: (270000, 271000)
# Beginning: (271000, 272000)
#    intitial query complete
#    extracted all rows. Saving SFrame..
# Completed: (271000, 272000)
# Beginning: (272000, 273000)
#    intitial query complete
#    extracted all rows. Saving SFrame..
# Completed: (272000, 273000)
# Beginning: (273000, 274000)
#    intitial query complete
#    extracted all rows. Saving SFrame..
# Completed: (273000, 274000)
# Beginning: (274000, 275000)
#    intitial query complete
#    extracted all rows. Saving SFrame..
# Completed: (274000, 275000)
# Beginning: (275000, 276000)
#    intitial query complete
#    extracted all rows. Saving SFrame..
# Completed: (275000, 276000)
# Beginning: (276000, 277000)
#    intitial query complete
#    extracted all rows. Saving SFrame..
# Completed: (276000, 277000)
# Beginning: (277000, 278000)
#    intitial query complete
#    extracted all rows. Saving SFrame..
# Completed: (277000, 278000)
# Beginning: (278000, 279000)
#    intitial query complete
#    extracted all rows. Saving SFrame..
# Completed: (278000, 279000)
# Beginning: (279000, 280000)
#    intitial query complete
#    extracted all rows. Saving SFrame..
# Completed: (279000, 280000)
# Beginning: (280000, 281000)
#    intitial query complete
#    extracted all rows. Saving SFrame..
# Completed: (280000, 281000)
# Beginning: (281000, 282000)
#    intitial query complete
#    extracted all rows. Saving SFrame..
# Completed: (281000, 282000)
# Beginning: (282000, 283000)
#    intitial query complete
#    extracted all rows. Saving SFrame..
# Completed: (282000, 283000)
# Beginning: (283000, 284000)
#    intitial query complete
#    extracted all rows. Saving SFrame..
# Completed: (283000, 284000)
# Beginning: (284000, 285000)
#    intitial query complete
#    extracted all rows. Saving SFrame..
# Completed: (284000, 285000)
# Beginning: (285000, 286000)
#    intitial query complete
#    extracted all rows. Saving SFrame..
# Completed: (285000, 286000)
# Beginning: (286000, 287000)
#    intitial query complete
#    extracted all rows. Saving SFrame..
# Completed: (286000, 287000)
# Beginning: (287000, 288000)
#    intitial query complete
#    extracted all rows. Saving SFrame..
# Completed: (287000, 288000)
# Beginning: (288000, 289000)
#    intitial query complete
#    extracted all rows. Saving SFrame..
# Completed: (288000, 289000)
# Beginning: (289000, 290000)
#    intitial query complete
#    extracted all rows. Saving SFrame..
# Completed: (289000, 290000)
# Beginning: (290000, 291000)
#    intitial query complete
#    extracted all rows. Saving SFrame..
# Completed: (290000, 291000)
# Beginning: (291000, 292000)
#    intitial query complete
#    extracted all rows. Saving SFrame..
# Completed: (291000, 292000)
# Beginning: (292000, 293000)
#    intitial query complete
#    extracted all rows. Saving SFrame..
# Completed: (292000, 293000)
# Beginning: (293000, 294000)
#    intitial query complete
#    extracted all rows. Saving SFrame..
# Completed: (293000, 294000)
# Beginning: (294000, 295000)
#    intitial query complete
#    extracted all rows. Saving SFrame..
# Completed: (294000, 295000)
# Beginning: (295000, 296000)
#    intitial query complete
#    extracted all rows. Saving SFrame..
# Completed: (295000, 296000)
# Beginning: (296000, 297000)
#    intitial query complete
#    extracted all rows. Saving SFrame..
# Completed: (296000, 297000)
# Beginning: (297000, 298000)
#    intitial query complete
#    extracted all rows. Saving SFrame..
# Completed: (297000, 298000)
# Beginning: (298000, 299000)
#    intitial query complete
#    extracted all rows. Saving SFrame..
# Completed: (298000, 299000)
# Beginning: (299000, 300000)
#    intitial query complete
#    extracted all rows. Saving SFrame..
# Completed: (299000, 300000)

# %% [markdown]
# #### We now combine these into a single data frame. Once this is processed and cleaned we will delete all temporary and intermediate data frames from the hard drive..

# %%
table = graphlab.SFrame('_temp_mimic_all_data_' + str(boundary_ids[0]))

for boundary in boundary_ids[1:]:
    print boundary
    new_table = graphlab.SFrame('_temp_mimic_all_data_' + str(boundary))
    table = table.append(new_table)
    
table.save('mimic_all_data')
# Out:
# (201000, 202000)
# (202000, 203000)
# (203000, 204000)
# (204000, 205000)
# (205000, 206000)
# (206000, 207000)
# (207000, 208000)
# (208000, 209000)
# (209000, 210000)
# (210000, 211000)
# (211000, 212000)
# (212000, 213000)
# (213000, 214000)
# (214000, 215000)
# (215000, 216000)
# (216000, 217000)
# (217000, 218000)
# (218000, 219000)
# (219000, 220000)
# (220000, 221000)
# (221000, 222000)
# (222000, 223000)
# (223000, 224000)
# (224000, 225000)
# (225000, 226000)
# (226000, 227000)
# (227000, 228000)
# (228000, 229000)
# (229000, 230000)
# (230000, 231000)
# (231000, 232000)
# (232000, 233000)
# (233000, 234000)
# (234000, 235000)
# (235000, 236000)
# (236000, 237000)
# (237000, 238000)
# (238000, 239000)
# (239000, 240000)
# (240000, 241000)
# (241000, 242000)
# (242000, 243000)
# (243000, 244000)
# (244000, 245000)
# (245000, 246000)
# (246000, 247000)
# (247000, 248000)
# (248000, 249000)
# (249000, 250000)
# (250000, 251000)
# (251000, 252000)
# (252000, 253000)
# (253000, 254000)
# (254000, 255000)
# (255000, 256000)
# (256000, 257000)
# (257000, 258000)
# (258000, 259000)
# (259000, 260000)
# (260000, 261000)
# (261000, 262000)
# (262000, 263000)
# (263000, 264000)
# (264000, 265000)
# (265000, 266000)
# (266000, 267000)
# (267000, 268000)
# (268000, 269000)
# (269000, 270000)
# (270000, 271000)
# (271000, 272000)
# (272000, 273000)
# (273000, 274000)
# (274000, 275000)
# (275000, 276000)
# (276000, 277000)
# (277000, 278000)
# (278000, 279000)
# (279000, 280000)
# (280000, 281000)
# (281000, 282000)
# (282000, 283000)
# (283000, 284000)
# (284000, 285000)
# (285000, 286000)
# (286000, 287000)
# (287000, 288000)
# (288000, 289000)
# (289000, 290000)
# (290000, 291000)
# (291000, 292000)
# (292000, 293000)
# (293000, 294000)
# (294000, 295000)
# (295000, 296000)
# (296000, 297000)
# (297000, 298000)
# (298000, 299000)
# (299000, 300000)

# %%
table = graphlab.SFrame('mimic_all_data/')
old_table = graphlab.SFrame('mimic_all_data_CLEANED_RFD/')

IN_IDS = table['C.ICUSTAY_ID'].unique()
O_IN_IDS = old_table['C.ICUSTAY_ID'].unique()

# %%
remaining_ids = [iid for iid in O_IN_IDS if iid not in IN_IDS]

# %%
print len(IN_IDS)
print len(O_IN_IDS)
# Out:
# 14430
# 11288

# %% [markdown]
# ### Appears to have worked, but cannot confirm until see how many rows in the cleaned dataset.

# %% [markdown]
# ----------------------------------------------------------------------------------------------
# ## (C) Post-processing of data.
#
# Having extracted the main data we perform some post-processing to facilitate anlysis.

# %%
all_data = graphlab.SFrame('mimic_all_data') ## reload
print all_data.column_names()

number_of_stays = len(all_data['C.ICUSTAY_ID'].unique())
print len(all_data)
print number_of_stays
# Out:
# ['C.CHARTTIME', 'C.HADM_ID', 'C.ICUSTAY_ID', 'C.ITEMID', 'C.SUBJECT_ID', 'C.VALUE', 'C.VALUENUM', 'C.VALUEUOM', 'D.LABEL', 'D.UNITNAME', 'II.INTIME', 'II.LOS', 'II.OUTTIME']
# 10841059
# 14430

# %% [markdown]
# *There are more than 10 million rows in the data (on disk this is just over 1.5gb saved). And there are 14426 unique ICUSTAYS, not all of these will be in the cohort).*

# %% [markdown]
# We add the following columns to the data:
#
# * ['final_4hr'] : 1 if measurement is from final 4 hours of patients stay
# * ['final_24hr'] : 1 if measurement is from final 24 hours of patients stay
# * ['hrs_bd'] : float giving number of hours before discharge that msrmnt was taken (can filter on this column later)

# %%
all_data['hrs_bd'] = (all_data['II.OUTTIME'] - all_data['C.CHARTTIME'])/float(60**2)
all_data.save('mimic_all_data')

# %%
HR = 4  ## number of hours before end of ICUSTAY 
all_data['final_%dhr' %HR] = all_data.apply(lambda row: 1 if (row['II.OUTTIME'] - row['C.CHARTTIME']).total_seconds()/(60.**2) <= HR else 0)
all_data.save('mimic_all_data')

# %%
HR = 24  ## number of hours before end of ICUSTAY 
all_data['final_%dhr' %HR] = all_data.apply(lambda row: 1 if (row['II.OUTTIME'] - row['C.CHARTTIME']).total_seconds()/(60.**2) <= HR else 0)
all_data.save('mimic_all_data')

# %% [markdown]
# #### Merging data extraction with cohort..
#
# We now add columns for cohort identification, and filtering based on outcome. Main cohort consists of the first ICUSTAY of each hospital admission (should be >13000 stays).
#
# From this cohort we are interested in ICUSTAYS that have good (1) and bad (0) outcome.
# The are two types of bad outcome: (A) in-hospital death, (B) readmission to ICU (during same hospital admission).
#
# The above abstraction is not fool-proof. For example:
# * patients may die outside of hospital for related reasons
# * readmission may be linked but occur on different stay
# * in-hopistal death may be unrelated to ICU discharge
# * etc
#
# We add the following columns to the data frame: **
#
# * ['cohort']: binary flag. 1 indicates that ICUSTAY is part of cohort (i.e. first or only stay of a hospital admission).
# * ['outcome']: binary flag. 1 indicates good outcome (survival with no readmission). 0 indicates bad outcome (death or readmission).
# * ['in_h_death']: binary flag. 1 for death. 0 for survival.
# * ['in_icu_death']: binary flag. 1 for death. 0 for survival.
# * ['readmit']: integer. Number of readmissions during same hospital admission.
#
# *Note: there are fewer HADMs than in cohort_selection_mimic.ipynb, since not all patients have chartevents data.*

# %%
f = open('first_stays.pkl', 'rb')
first_stays = pickle.load(f)
f.close()

f = open('moratlities.pkl', 'rb')
mortalities = pickle.load(f)
f.close()

f = open('stay_counts.pkl', 'rb')
stays_counts = pickle.load(f)
f.close()

f = open('icu_deaths.pkl', 'rb')
ic_deaths = pickle.load(f)
f.close()

# %%
print "Adding cohort column..."
all_data['cohort'] = all_data.apply(lambda row: 1 if first_stays[row['C.HADM_ID']]==row['C.ICUSTAY_ID'] else 0)

print "Adding in hospital column..."
all_data['in_h_death'] = all_data['C.HADM_ID'].apply(lambda hadmid: 1 if hadmid in mortalities else 0 )

print "Adding in icu death column..."
all_data['in_icu_death'] = all_data['C.ICUSTAY_ID'].apply(lambda icustay: 1 if icustay in ic_deaths else 0 )

print "Adding readmission column..."
all_data['readmit'] = all_data['C.HADM_ID'].apply(lambda hadmid: stays_counts[hadmid] - 1)

print "Adding outcome column..."
all_data['outcome'] = all_data['C.HADM_ID'].apply(lambda hadmid: 1 if (hadmid not in mortalities and stays_counts[hadmid]==1) else 0)

print 'finish adding new columns, saving data frame..'
all_data.save('mimic_all_data')
# Out:
# Adding cohort column...
# Adding in hospital column...
# Adding in icu death column...
# Adding readmission column...
# Adding outcome column...
# finish adding new columns, saving data frame..

# %%
len(all_data['C.ICUSTAY_ID'].unique())
# Out:
# 14430
